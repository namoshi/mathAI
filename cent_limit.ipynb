# %% [markdown]
# <a href="https://colab.research.google.com/github/namoshi/mathAI/blob/master/cent_limit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
X = np.random.rand(10000)

plt.hist(X, bins=30, range=(0.0, 1.0))
plt.show()

# %%
X1 = np.random.rand(10000)
X2 = np.random.rand(10000)

X = (X1 + X2)/2

plt.hist(X, bins=30, range=(0.0, 1.0))
plt.show()

# %%
n= 5
X=np.zeros(10000)
for i in range(n):
  X = X + np.random.rand(10000)

X=X/n
plt.hist(X, bins=30, range=(0.0, 1.0))
plt.show()

# %%
n= 10
X=np.zeros(10000)
for i in range(n):
  X = X + np.random.rand(10000)

X=X/n
plt.hist(X, bins=50, range=(0.0, 1.0))
plt.show()

# %%
n= 100
X=np.zeros(10000)
for i in range(n):
  X = X + np.random.rand(10000)

X=X/n
plt.hist(X, bins=100, range=(0.0, 1.0))
plt.show()
